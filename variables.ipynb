# %%
# variables

# %%
name = "shamsheer" # name is a variable here
print(name)
print(id(name))
# Out:
# shamsheer
# 4507056176

# %%
age = 23
print(age)
print(id(age))
# Out:
# 23
# 4396821624

# %%
# same values will be in the same memory location
score = 23
salary = 25
print(id(score))
print(id(salary))
# Out:
# 4396821624
# 4396821688

# %%
# 256 --> IDE

# %% [markdown]
# ### rules and ragulation of the variables

# %% [markdown]
# #### variable can't be start from a number

# %%
12 = "raziul"
# Out:
#   Cell In[8], line 1
#     12 = "raziul"
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %% [markdown]
# #### special char and space ( _ )

# %%
student!name = "shamsheer"
# Out:
#   Cell In[10], line 1
#     student!name = "shamsheer"
#            ^
# SyntaxError: invalid syntax

# %% [markdown]
# #### python is a case senstive programming lang

# %%
Dog = "ruby"
print(dog)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 Dog = "ruby"
# ----> 2 print(dog)
#
# NameError: name 'dog' is not defined

# %% [markdown]
# #### variable can't be a keyword

# %%
# reserve words ---> variable,file name,class,function

# %%
if = "shama"
# Out:
#   Cell In[13], line 1
#     if = "shama"
#        ^
# SyntaxError: invalid syntax

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
name3 = "False"
print(name3)
# Out:
# False

# %% [markdown]
# #### best way to create a variable

# %%
name_of_student = "shamsheer"
print(name_of_student)
# Out:
# shamsheer

# %%
second_per_min = 12

# %%
name13 = "jiger"
print(name13)
# Out:
# jiger

# %%
# snake case ___ 
# camel case --> AserD (avoid this)

# %%
# comments ?  ---> notes

# %%
# nfad
# dfdfal
# faodj

# %%
# ctrl + /
