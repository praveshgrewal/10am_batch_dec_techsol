# %%
"5"+"5"
# Out:
# '55'

# %%
5+5
# Out:
# 10

# %%
"Python" * 2
# Out:
# 'PythonPython'

# %%
print("welcome in python")
# Out:
# welcome in python

# %%
name = "saad"
print(name)
# Out:
# saad

# %%
num = 12
num2 = 12
print(num*num2)
# Out:
# 144

# %%
age = 35
print(type(age))
print(age)
# Out:
# <class 'int'>
# 35

# %%
num4 = "100"
print(type(num4))

new_num = float(num4)
print(type(new_num))
print(new_num)
# Out:
# <class 'str'>
# <class 'float'>
# 100.0

# %%
name4 = float(input('Enter a number '))
print(name4)
print(type(name4))
# Out:
# 89.0
# <class 'float'>

# %%
x = 10
y = 3
print(x//y)
# Out:
# 3

# %%
a = 2
b =5
print(a**b)
# Out:
# 32

# %%
print("Pytohn"+" Programming")
# Out:
# Pytohn Programming

# %%
name5 = "python "
name6 = "programming"
print(name5 + " " + name6)
# Out:
# python  programming
