# %%
text = "my name is saad i am learnining python programming"

# %%
name = "mudabir"
print(name)
print(id(name))
# Out:
# mudabir
# 4506581968

# %%
age = 23
print(age)
print(id(age))
# Out:
# 23
# 4397395064
